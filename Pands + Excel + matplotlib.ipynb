# %%
import pandas as pd

df = pd.read_excel("daten.xlsx")
df.head()
# Out:
#    Jahr  Umsatz
# 0  1900     230
# 1  1901     296
# 2  1902     297
# 3  1903     107
# 4  1904     167

# %%
year = df["Jahr"]
sales = df["Umsatz"]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(year, sales)
plt.show()
